# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_rows",200)
pd.set_option("display.max_columns",50)

# %%
df=pd.read_csv("company.csv")

# %%
#df1=pd.read_csv("employee.txt",sep=",")

# %%
df
# Out:
#                        Company   Age  Salary       Place Country  Gender
# 0                          TCS  20.0     NaN     Chennai   India       0
# 1                      Infosys  30.0     NaN      Mumbai   India       0
# 2                          TCS  35.0  2300.0    Calcutta   India       0
# 3                      Infosys  40.0  3000.0       Delhi   India       0
# 4                          TCS  23.0  4000.0      Mumbai   India       0
# 5                      Infosys   NaN  5000.0    Calcutta   India       0
# 6                          TCS   NaN  6000.0     Chennai   India       1
# 7                      Infosys  23.0  7000.0      Mumbai   India       1
# 8                          TCS  34.0  8000.0    Calcutta   India       1
# 9                          CTS  45.0  9000.0       Delhi   India       0
# 10                         CTS  23.0     NaN      Mumbai   India       0
# 11                         CTS  34.0  1089.0    Calcutta   India       0
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary', 'Place', 'Country', 'Gender'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  140 non-null    object
#  1   Age      130 non-null    float64
#  2   Salary   124 non-null    float64
#  3   Place    134 non-null    object
#  4   Country  148 non-null    object
#  5   Gender   148 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 7.1+ KB

# %%
df.describe()
# Out:
#               Age       Salary      Gender
# count  130.000000   124.000000  148.000000
# mean    30.484615  5312.467742    0.222973
# std     11.096640  2573.764683    0.417654
# min      0.000000  1089.000000    0.000000
# 25%     22.000000  3030.000000    0.000000
# 50%     32.500000  5000.000000    0.000000
# 75%     37.750000  8000.000000    0.000000
# max     54.000000  9876.000000    1.000000

# %%
df.head()
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
df.tail()
# Out:
#      Company   Age  Salary     Place Country  Gender
# 143      TCS  33.0  9024.0  Calcutta   India       1
# 144  Infosys  22.0  8787.0  Calcutta   India       1
# 145  Infosys  44.0  4034.0     Delhi   India       1
# 146      TCS  33.0  5034.0    Mumbai   India       1
# 147  Infosys  22.0  8202.0    Cochin   India       0

# %%
df.iloc[100:111,[0,3,4]]
# Out:
#      Company       Place Country
# 100      CTS      Cochin   India
# 101      CTS  Podicherry   India
# 102      CTS      Mumbai   India
# 103      CTS    Calcutta   India
# 104  Infosys       Delhi   India
# 105      TCS      Mumbai   India
# 106  Infosys      Cochin   India
# 107      TCS     Chennai   India
# 108      TCS      Mumbai   India
# 109      NaN    Calcutta   India
# 110      TCS       Delhi   India

# %%
df.loc[100:105,["Company","Age","Country"]]
# Out:
#      Company   Age Country
# 100      CTS  22.0   India
# 101      CTS   0.0   India
# 102      CTS  44.0   India
# 103      CTS  22.0   India
# 104  Infosys  44.0   India
# 105      TCS  33.0   India

# %%
df.loc[100,["Company","Age","Country"]]
# Out:
# Company      CTS
# Age         22.0
# Country    India
# Name: 100, dtype: object

# %%
df[(df['Place']=="Chennai") & (df['Gender']==1)]
# Out:
#     Company  Age  Salary    Place Country  Gender
# 6       TCS  NaN  6000.0  Chennai   India       1
# 24      TCS  NaN  7084.0  Chennai   India       1
# 107     TCS  0.0  9024.0  Chennai   India       1

# %%
df.query('Place=="Chennai" & Gender==1')
# Out:
#     Company  Age  Salary    Place Country  Gender
# 6       TCS  NaN  6000.0  Chennai   India       1
# 24      TCS  NaN  7084.0  Chennai   India       1
# 107     TCS  0.0  9024.0  Chennai   India       1

# %%
df.query('Age<50 & Company=="TCS" & Place=="Mumbai"')
# Out:
#     Company   Age  Salary   Place Country  Gender
# 4       TCS  23.0  4000.0  Mumbai   India       0
# 22      TCS  21.0  4824.0  Mumbai   India       0
# 54      TCS  21.0  6544.0  Mumbai   India       0
# 71      TCS  34.0  9024.0  Mumbai   India       1
# 74      TCS  37.0  2300.0  Mumbai   India       0
# 87      TCS  21.0  3000.0  Mumbai   India       0
# 90      TCS  21.0     NaN  Mumbai   India       0
# 105     TCS  33.0  5034.0  Mumbai   India       0
# 108     TCS  33.0     NaN  Mumbai   India       0
# 130     TCS  21.0  4824.0  Mumbai   India       0
# 146     TCS  33.0  5034.0  Mumbai   India       1

# %% [markdown]
# # HANDLING THE NULL / MISSING DATA

# %%
df.head()
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
df['Company'].mode()
# Out:
# 0    TCS
# dtype: object

# %%
df['Company'].replace(np.nan,'TCS',inplace=True)

# %%
df['Age'].min()
# Out:
# 0.0

# %%
df['Age'].max()
# Out:
# 54.0

# %%
df['Age'].mean()
# Out:
# 30.484615384615385

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Company'].value_counts()
# Out:
# TCS                          61
# Infosys                      45
# CTS                          36
# Tata Consultancy Services     2
# Infosys Pvt Lmt               2
# Congnizant                    2
# Name: Company, dtype: int64

# %%
df['Company'].replace({'Tata Consultancy Services':'TCS','Infosys Pvt Lmt':'Infosys','Congnizant':'CTS'},inplace=True)

# %%
df['Company'].value_counts()
# Out:
# TCS        63
# Infosys    47
# CTS        38
# Name: Company, dtype: int64

# %%
df.head()
# Out:
#    Company   Age  Salary     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0

# %%
df.rename(columns={'Salary':'Pay'},inplace=True)

# %%
df.head()
# Out:
#    Company   Age     Pay     Place Country  Gender
# 0      TCS  20.0     NaN   Chennai   India       0
# 1  Infosys  30.0     NaN    Mumbai   India       0
# 2      TCS  35.0  2300.0  Calcutta   India       0
# 3  Infosys  40.0  3000.0     Delhi   India       0
# 4      TCS  23.0  4000.0    Mumbai   India       0
